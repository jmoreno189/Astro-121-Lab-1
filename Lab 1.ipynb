# %% [markdown]
# # Lab 1: Digital Sampling, Fourier Filtering, and Heterodyne Mixers
# **Author:** Joseph Moreno
# **Collaborators:** Kaitlyn Le, Kennedy Haynes, Helena
# **Date:** 8 February 2026
#
# ---
#
# ### Software Installation
# This report utilizes the UC Berkeley ASTRON 121 ugradio Python package as part of the data collection process. Additionally, this Jupyter Notebook requires installation of a custom package created by the author for data analysis. Use the cell below to install this package:
#
# ```python
# # Installation command for the custom package
# !pip install git+[https://github.com/](https://github.com/)[jmoreno189]/[Your-Repo-Name].git

# %% [markdown]
# # I. Abstract

# %% [markdown]
# # II. Introduction

# %% [markdown]
# # III. Lab Setup

# %% [markdown]
# # IV. Data Collection Methodology

# %% [markdown]
# # V. Results

# %% [markdown]
# # VI. Analysis and Discussion
